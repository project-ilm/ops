# %% [markdown]
# # ILM / misty-doi — Quickstart
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/project-ilm/ops/blob/main/notebooks/ilm_quickstart.ipynb) [![Kaggle](https://kaggle.com/static/images/open-in-kaggle.svg)](https://kaggle.com/kernels/welcome?src=https://github.com/project-ilm/ops/blob/main/notebooks/ilm_quickstart.ipynb)
#
# Runs the ILM tools on free cloud compute — no local install.

# %%
# !pip -q install misty-doi
# !pip -q install git+https://github.com/project-ilm/spi-scan.git
# !misty --help | head -5
# !spi-scan --help | head -5

# %%
# !git clone -q https://github.com/project-ilm/misty-doi.git
# !spi-scan git ./misty-doi || echo 'exit 7 = HIGH findings'

# %%
# !misty init -o metadata.json && cat metadata.json
